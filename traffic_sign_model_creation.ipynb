# %%
import os
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense

# %%
data = []
labels = []
classes = 43
data_dir = 'datasets'

for i in range(classes):
    path = os.path.join(data_dir, 'Train', str(i))
    images = os.listdir(path)

    for img_name in images:
        try:
            image = cv2.imread(os.path.join(path, img_name))
            image_resized = cv2.resize(image, (32, 32))
            
            data.append(image_resized)
            labels.append(i)
        except Exception as e:
            print(f"Error loading image: {img_name} with error {e}")

data = np.array(data)
labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

num_classes = 43
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

model = Sequential()
model.add(keras.Input(shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))

model.add(Dense(43, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, batch_size=64, epochs=15, validation_data=(X_test, y_test))

model.save("traffic_sign_model.keras")
# Out:
# Epoch 1/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.5847 - loss: 1.5108 - val_accuracy: 0.9240 - val_loss: 0.3127
# Epoch 2/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.8893 - loss: 0.3707 - val_accuracy: 0.9797 - val_loss: 0.1305
# Epoch 3/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9362 - loss: 0.2153 - val_accuracy: 0.9844 - val_loss: 0.0842
# Epoch 4/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9557 - loss: 0.1467 - val_accuracy: 0.9883 - val_loss: 0.0516
# Epoch 5/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9679 - loss: 0.1108 - val_accuracy: 0.9926 - val_loss: 0.0356
# Epoch 6/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9717 - loss: 0.0911 - val_accuracy: 0.9939 - val_loss: 0.0315
# Epoch 7/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9748 - loss: 0.0825 - val_accuracy: 0.9946 - val_loss: 0.0286
# Epoch 8/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9801 - loss: 0.0648 - val_accuracy: 0.9949 - val_loss: 0.0226
# Epoch 9/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9811 - loss: 0.0603 - val_accuracy: 0.9935 - val_loss: 0.0258
# Epoch 10/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9835 - loss: 0.0545 - val_accuracy: 0.9960 - val_loss: 0.0200
# Epoch 11/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9866 - loss: 0.0449 - val_accuracy: 0.9953 - val_loss: 0.0191
# Epoch 12/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9866 - loss: 0.0418 - val_accuracy: 0.9953 - val_loss: 0.0191
# Epoch 13/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9871 - loss: 0.0411 - val_accuracy: 0.9954 - val_loss: 0.0232
# Epoch 14/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9880 - loss: 0.0388 - val_accuracy: 0.9955 - val_loss: 0.0214
# Epoch 15/15
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9864 - loss: 0.0432 - val_accuracy: 0.9953 - val_loss: 0.0220
